# %% [markdown]
# <a href="https://colab.research.google.com/github/saloniganvir2004-sketch/ML_Practicals/blob/main/ML_Practicals/Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("/content/students_data.csv")
print("Original Dataset:")
print(df)
# Out:
# Original Dataset:
#    Student_ID    Name   Age  Gender  Marks    City
# 0         101   Anita  18.0  Female   85.0  Nagpur
# 1         102   Rahul  19.0    Male   78.0     NaN
# 2         103  Simran   NaN  Female   92.0  Mumbai
# 3         104    Amit  20.0    Male    NaN    Pune
# 4         105     NaN  18.0  Female   88.0  Nagpur
# 5         106    Riya  21.0  Female   95.0   Delhi

# %%
print("\nNull Values in Each Column:")
print(df.isnull().sum())
# Out:
# Null Values in Each Column:
# Student_ID    0
# Name          1
# Age           1
# Gender        0
# Marks         1
# City          1
# dtype: int64

# %%
df['Marks'] = df['Marks'].fillna(df['Marks'].mean())
df['Age'] = df['Age'].fillna(df['Age'].median())
df['City'] = df['City'].fillna('Unknown')
df['Name'] = df['Name'].fillna('NoName')
df
# Out:
#    Student_ID    Name   Age  Gender  Marks     City
# 0         101   Anita  18.0  Female   85.0   Nagpur
# 1         102   Rahul  19.0    Male   78.0  Unknown
# 2         103  Simran  19.0  Female   92.0   Mumbai
# 3         104    Amit  20.0    Male   87.6     Pune
# 4         105  NoName  18.0  Female   88.0   Nagpur
# 5         106    Riya  21.0  Female   95.0    Delhi

# %%
new_row = {'Student_ID': 107, 'Name': 'Kabir', 'Age': 22, 'Gender': 'Male', 'Marks': 89, 'City': 'Chennai'}
df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
df
# Out:
#    Student_ID    Name   Age  Gender  Marks     City
# 0         101   Anita  18.0  Female   85.0   Nagpur
# 1         102   Rahul  19.0    Male   78.0  Unknown
# 2         103  Simran  19.0  Female   92.0   Mumbai
# 3         104    Amit  20.0    Male   87.6     Pune
# 4         105  NoName  18.0  Female   88.0   Nagpur
# 5         106    Riya  21.0  Female   95.0    Delhi
# 6         107   Kabir  22.0    Male   89.0  Chennai
# 7         107   Kabir  22.0    Male   89.0  Chennai
# 8         107   Kabir  22.0    Male   89.0  Chennai

# %%
df = df.drop(df.index[2])
df
# Out:
#    Student_ID    Name   Age  Gender  Marks     City
# 0         101   Anita  18.0  Female   85.0   Nagpur
# 1         102   Rahul  19.0    Male   78.0  Unknown
# 4         105  NoName  18.0  Female   88.0   Nagpur
# 5         106    Riya  21.0  Female   95.0    Delhi
# 6         107   Kabir  22.0    Male   89.0  Chennai
# 7         107   Kabir  22.0    Male   89.0  Chennai
# 8         107   Kabir  22.0    Male   89.0  Chennai

# %%
df = df.drop(columns=['Gender'])
df
# Out:
#    Student_ID    Name   Age  Marks     City
# 0         101   Anita  18.0   85.0   Nagpur
# 1         102   Rahul  19.0   78.0  Unknown
# 4         105  NoName  18.0   88.0   Nagpur
# 5         106    Riya  21.0   95.0    Delhi
# 6         107   Kabir  22.0   89.0  Chennai
# 7         107   Kabir  22.0   89.0  Chennai
# 8         107   Kabir  22.0   89.0  Chennai

# %%
df['Grade'] = ['A', 'B', 'A', 'B', 'A','A', 'A']
df
# Out:
#    Student_ID    Name   Age  Marks     City Grade
# 0         101   Anita  18.0   85.0   Nagpur     A
# 1         102   Rahul  19.0   78.0  Unknown     B
# 4         105  NoName  18.0   88.0   Nagpur     A
# 5         106    Riya  21.0   95.0    Delhi     B
# 6         107   Kabir  22.0   89.0  Chennai     A
# 7         107   Kabir  22.0   89.0  Chennai     A
# 8         107   Kabir  22.0   89.0  Chennai     A
