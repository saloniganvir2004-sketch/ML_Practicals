# %% [markdown]
# <a href="https://colab.research.google.com/github/saloniganvir2004-sketch/ML_Practicals/blob/main/ML_Practicals/manipulation_and_rescaling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/Student_Scores.csv')
df
# Out:
#      Name  Age  Hours_Studied  Test_Score
# 0   Rahul   18            2.5          55
# 1   Priya   19            3.0          60
# 2   Arjun   17            4.5          75
# 3    Neha   18            5.0          82
# 4  Anjali   19            1.5          45
# 5   Rohit   18            3.5          65
# 6   Sneha   20            4.0          70
# 7   Karan   21            2.0          50
# 8   Meena   17            6.0          90
# 9    Riya   19            5.5          88

# %%
print("Original Data:\n",df, "\n")
# Out:
# Original Data:
#       Name  Age  Hours_Studied  Test_Score
# 0   Rahul   18            2.5          55
# 1   Priya   19            3.0          60
# 2   Arjun   17            4.5          75
# 3    Neha   18            5.0          82
# 4  Anjali   19            1.5          45
# 5   Rohit   18            3.5          65
# 6   Sneha   20            4.0          70
# 7   Karan   21            2.0          50
# 8   Meena   17            6.0          90
# 9    Riya   19            5.5          88

# %%
print("Missing values:\n", df.isnull().sum(), "\n")
# Out:
# Missing values:
#  Name             0
# Age              0
# Hours_Studied    0
# Test_Score       0
# dtype: int64

# %%
df= df.fillna(df.select_dtypes(include=[np.number]).mean())
df.rename(columns={'Test_Score': 'Score'}, inplace=True)
df
# Out:
#      Name  Age  Hours_Studied  Score
# 0   Rahul   18            2.5     55
# 1   Priya   19            3.0     60
# 2   Arjun   17            4.5     75
# 3    Neha   18            5.0     82
# 4  Anjali   19            1.5     45
# 5   Rohit   18            3.5     65
# 6   Sneha   20            4.0     70
# 7   Karan   21            2.0     50
# 8   Meena   17            6.0     90
# 9    Riya   19            5.5     88

# %%
num = df.select_dtypes(include=[np.number])
normalized = (num - num.min()) / (num.max() - num.min())
standardized = (num - num.mean()) / num.std()
print("Normalized Data:\n", normalized)
print("\nStandardized Data:\n", standardized)
# Out:
# Normalized Data:
#      Age  Hours_Studied     Score
# 0  0.25       0.222222  0.222222
# 1  0.50       0.333333  0.333333
# 2  0.00       0.666667  0.666667
# 3  0.25       0.777778  0.822222
# 4  0.50       0.000000  0.000000
# 5  0.25       0.444444  0.444444
# 6  0.75       0.555556  0.555556
# 7  1.00       0.111111  0.111111
# 8  0.00       1.000000  1.000000
# 9  0.50       0.888889  0.955556
#
# Standardized Data:
#          Age  Hours_Studied     Score
# 0 -0.474342      -0.825723 -0.826242
# 1  0.316228      -0.495434 -0.508456
# 2 -1.264911       0.495434  0.444899
# 3 -0.474342       0.825723  0.889799
# 4  0.316228      -1.486301 -1.461812
# 5 -0.474342      -0.165145 -0.190671
# 6  1.106797       0.165145  0.127114
# 7  1.897367      -1.156012 -1.144027
# 8 -1.264911       1.486301  1.398255
# 9  0.316228       1.156012  1.271141
